# %%
import json 
import os 

task="social_message"
av_file="/proj/digbose92/ads_repo/model_files/predictions/class_wise/av_result_"+task+".json"
tv_file="/proj/digbose92/ads_repo/model_files/predictions/class_wise/tv_result_"+task+".json"
a_max_file="/proj/digbose92/ads_repo/model_files/predictions/class_wise/"+task+"_avg_max_class_wise.json"
d_max_file="/proj/digbose92/ads_repo/model_files/predictions/class_wise/"+task+"_double_max_class_wise.json"


with open(av_file, "r") as f:
    av_data=json.load(f)
    
with open(tv_file, "r") as f:
    tv_data=json.load(f)
    
with open(a_max_file, "r") as f:
    a_max_data=json.load(f)
    
with open(d_max_file, "r") as f:
    d_max_data=json.load(f)

# %%
av_data
# Out:
# {'run_0': {'seed': 1209,
#   'accuracy': 0.6122931442080378,
#   'f1_score': 0.48977588410348516,
#   'f1_score_class_wise': {'Games': 0.5862068965517241,
#    'Household': 0.44155844155844154,
#    'Services': 0.4161073825503356,
#    'Misc': 0.459016393442623,
#    'Sports': 0.3913043478260869,
#    'Banking': 0.4303797468354431,
#    'Clothing': 0.5287356321839081,
#    'Industrial and agriculture': 0.425531914893617,
#    'Leisure': 0.4371584699453552,
#    'Publications media': 0.16666666666666666,
#    'Health': 0.49681528662420377,
#    'Car': 0.802588996763754,
#    'Electronics': 0.6153846153846154,
#    'Cosmetics': 0.3548387096774194,
#    'Food and drink': 0.7393800229621126,
#    'Awareness': 0.6642335766423357,
#    'Travel and transport': 0.5673758865248226,
#    'Retail': 0.2926829268292683},
#   'acc_score_class_wise': {'Games': 0.6666666666666666,
#    'Household': 0.3953488372093023,
#    'Services': 0.4025974025974026,
#    'Misc': 0.358974358974359,
#    'Sports': 0.34615384615384615,
#    'Banking': 0.38636363636363635,
#    'Clothing': 0.5227272727272727,
#    'Industrial and agriculture': 0.4166666666666667,
#    'Leisure': 0.4819277108433735,
#    'Publications media': 0.1111111111111111,
#    'Health': 0.527027027027027,
#    'Car': 0.7469879518072289,
#    'Electronics': 0.5443786982248521,
#    'Cosmetics': 0.2391304347826087,
#    'Food and drink': 0.8586666666666667,
#    'Awareness': 0.6920152091254753,
#    'Travel and transport': 0.4819277108433735,
#    'Retail': 0.2608695652173913}},
#  'run_1': {'seed': 76247,
#   'accuracy': 0.6146572104018913,
#   'f1_score': 0.47641668552977545,
#   'f1_score_class_wise': {'Games': 0.5940594059405941,
#    'Household': 0.5161290322580644,
#    'Services': 0.32894736842105265,
#    'Misc': 0.4230769230769231,
#    'Sports': 0.28571428571428575,
#    'Banking': 0.46913580246913583,
#    'Clothing': 0.5510204081632653,
#    'Industrial and agriculture': 0.49056603773584906,
#    'Leisure': 0.4455445544554455,
#    'Publications media': 0.0,
#    'Health': 0.46428571428571425,
#    'Car': 0.819672131147541,
#    'Electronics': 0.6101694915254237,
#    'Cosmetics': 0.3384615384615385,
#    'Food and drink': 0.7651515151515151,
#    'Awareness': 0.6713286713286712,
#    'Travel and transport': 0.6257668711656442,
#    'Retail': 0.1764705882352941},
#   'acc_score_class_wise': {'Games': 0.5882352941176471,
#    'Household': 0.5581395348837209,
#    'Services': 0.3246753246753247,
#    'Misc': 0.28205128205128205,
#    'Sports': 0.19230769230769232,
#    'Banking': 0.4318181818181818,
#    'Clothing': 0.6136363636363636,
#    'Industrial and agriculture': 0.5416666666666666,
#    'Leisure': 0.5421686746987951,
#    'Publications media': 0.0,
#    'Health': 0.527027027027027,
#    'Car': 0.7530120481927711,
#    'Electronics': 0.5325443786982249,
#    'Cosmetics': 0.2391304347826087,
#    'Food and drink': 0.808,
#    'Awareness': 0.7300380228136882,
#    'Travel and transport': 0.6144578313253012,
#    'Retail': 0.13043478260869565}},
#  'run_2': {'seed': 58542,
#   'accuracy': 0.6252955082742316,
#   'f1_score': 0.491843797180246,
#   'f1_score_class_wise': {'Games': 0.625,
#    'Household': 0.3917525773195876,
#    'Services': 0.42519685039370075,
#    'Misc': 0.4848484848484849,
#    'Sports': 0.33333333333333337,
#    'Banking': 0.4533333333333333,
#    'Clothing': 0.5079365079365079,
#    'Industrial and agriculture': 0.4888888888888889,
#    'Leisure': 0.49101796407185627,
#    'Publications media': 0.0,
#    'Health': 0.513888888888889,
#    'Car': 0.7633136094674557,
#    'Electronics': 0.6215384615384616,
#    'Cosmetics': 0.48275862068965514,
#    'Food and drink': 0.7932379713914175,
#    'Awareness': 0.6785714285714285,
#    'Travel and transport': 0.5485714285714285,
#    'Retail': 0.25},
#   'acc_score_class_wise': {'Games': 0.6862745098039216,
#    'Household': 0.4418604651162791,
#    'Services': 0.35064935064935066,
#    'Misc': 0.41025641025641024,
#    'Sports': 0.3076923076923077,
#    'Banking': 0.38636363636363635,
#    'Clothing': 0.5454545454545454,
#    'Industrial and agriculture': 0.4583333333333333,
#    'Leisure': 0.4939759036144578,
#    'Publications media': 0.0,
#    'Health': 0.5,
#    'Car': 0.7771084337349398,
#    'Electronics': 0.5976331360946746,
#    'Cosmetics': 0.45652173913043476,
#    'Food and drink': 0.8133333333333334,
#    'Awareness': 0.7224334600760456,
#    'Travel and transport': 0.5783132530120482,
#    'Retail': 0.21739130434782608}},
#  'run_3': {'seed': 49884,
#   'accuracy': 0.6134751773049646,
#   'f1_score': 0.48206990813216677,
#   'f1_score_class_wise': {'Games': 0.6181818181818182,
#    'Household': 0.4466019417475728,
#    'Services': 0.3829787234042553,
#    'Misc': 0.4,
#    'Sports': 0.4,
#    'Banking': 0.35714285714285715,
#    'Clothing': 0.5333333333333333,
#    'Industrial and agriculture': 0.4,
#    'Leisure': 0.3709677419354839,
#    'Publications media': 0.16,
#    'Health': 0.46896551724137936,
#    'Car': 0.7886435331230285,
#    'Electronics': 0.5999999999999999,
#    'Cosmetics': 0.5714285714285715,
#    'Food and drink': 0.782608695652174,
#    'Awareness': 0.6571936056838367,
#    'Travel and transport': 0.5853658536585366,
#    'Retail': 0.15384615384615383},
#   'acc_score_class_wise': {'Games': 0.6666666666666666,
#    'Household': 0.5348837209302325,
#    'Services': 0.35064935064935066,
#    'Misc': 0.28205128205128205,
#    'Sports': 0.4230769230769231,
#    'Banking': 0.3409090909090909,
#    'Clothing': 0.6818181818181818,
#    'Industrial and agriculture': 0.3333333333333333,
#    'Leisure': 0.27710843373493976,
#    'Publications media': 0.1111111111111111,
#    'Health': 0.4594594594594595,
#    'Car': 0.7530120481927711,
#    'Electronics': 0.621301775147929,
#    'Cosmetics': 0.6086956521739131,
#    'Food and drink': 0.792,
#    'Awareness': 0.7034220532319392,
#    'Travel and transport': 0.5783132530120482,
#    'Retail': 0.08695652173913043}},
#  'run_4': {'seed': 40856,
#   'accuracy': 0.6152482269503546,
#   'f1_score': 0.49324341779222525,
#   'f1_score_class_wise': {'Games': 0.6315789473684211,
#    'Household': 0.4705882352941176,
#    'Services': 0.45255474452554745,
#    'Misc': 0.36065573770491804,
#    'Sports': 0.3076923076923077,
#    'Banking': 0.47368421052631576,
#    'Clothing': 0.4973544973544973,
#    'Industrial and agriculture': 0.4615384615384615,
#    'Leisure': 0.4367816091954023,
#    'Publications media': 0.14285714285714285,
#    'Health': 0.5072463768115941,
#    'Car': 0.7515527950310559,
#    'Electronics': 0.6005509641873278,
#    'Cosmetics': 0.42666666666666664,
#    'Food and drink': 0.7978290366350068,
#    'Awareness': 0.6666666666666666,
#    'Travel and transport': 0.5882352941176471,
#    'Retail': 0.30434782608695654},
#   'acc_score_class_wise': {'Games': 0.7058823529411765,
#    'Household': 0.46511627906976744,
#    'Services': 0.4025974025974026,
#    'Misc': 0.28205128205128205,
#    'Sports': 0.38461538461538464,
#    'Banking': 0.4090909090909091,
#    'Clothing': 0.5340909090909091,
#    'Industrial and agriculture': 0.5,
#    'Leisure': 0.4578313253012048,
#    'Publications media': 0.1111111111111111,
#    'Health': 0.47297297297297297,
#    'Car': 0.7289156626506024,
#    'Electronics': 0.6449704142011834,
#    'Cosmetics': 0.34782608695652173,
#    'Food and drink': 0.784,
#    'Awareness': 0.6996197718631179,
#    'Travel and transport': 0.6024096385542169,
#    'Retail': 0.30434782608695654}}}

# %%
tv_data
# Out:
# {'run_0': {'seed': 91752,
#   'accuracy': 0.6217494089834515,
#   'f1_score': 0.516921880658078,
#   'f1_score_class_wise': {'Games': 0.66,
#    'Household': 0.5263157894736843,
#    'Services': 0.406015037593985,
#    'Misc': 0.5757575757575758,
#    'Sports': 0.3571428571428571,
#    'Banking': 0.5777777777777778,
#    'Clothing': 0.45517241379310347,
#    'Industrial and agriculture': 0.5652173913043478,
#    'Leisure': 0.5411764705882354,
#    'Publications media': 0.06896551724137931,
#    'Health': 0.4166666666666667,
#    'Car': 0.7902735562310031,
#    'Electronics': 0.5942492012779553,
#    'Cosmetics': 0.423728813559322,
#    'Food and drink': 0.7764705882352941,
#    'Awareness': 0.6566604127579738,
#    'Travel and transport': 0.6203208556149733,
#    'Retail': 0.2926829268292683},
#   'acc_score_class_wise': {'Games': 0.6470588235294118,
#    'Household': 0.5813953488372093,
#    'Services': 0.35064935064935066,
#    'Misc': 0.48717948717948717,
#    'Sports': 0.38461538461538464,
#    'Banking': 0.5909090909090909,
#    'Clothing': 0.375,
#    'Industrial and agriculture': 0.5416666666666666,
#    'Leisure': 0.5542168674698795,
#    'Publications media': 0.05555555555555555,
#    'Health': 0.47297297297297297,
#    'Car': 0.7831325301204819,
#    'Electronics': 0.5502958579881657,
#    'Cosmetics': 0.5434782608695652,
#    'Food and drink': 0.792,
#    'Awareness': 0.6653992395437263,
#    'Travel and transport': 0.6987951807228916,
#    'Retail': 0.2608695652173913}},
#  'run_1': {'seed': 84059,
#   'accuracy': 0.6382978723404256,
#   'f1_score': 0.5236719099682072,
#   'f1_score_class_wise': {'Games': 0.660377358490566,
#    'Household': 0.4883720930232558,
#    'Services': 0.3968253968253968,
#    'Misc': 0.5588235294117647,
#    'Sports': 0.35999999999999993,
#    'Banking': 0.56,
#    'Clothing': 0.542713567839196,
#    'Industrial and agriculture': 0.4090909090909091,
#    'Leisure': 0.4999999999999999,
#    'Publications media': 0.2580645161290323,
#    'Health': 0.47058823529411764,
#    'Car': 0.8124999999999999,
#    'Electronics': 0.6277777777777778,
#    'Cosmetics': 0.4507042253521127,
#    'Food and drink': 0.7863247863247864,
#    'Awareness': 0.6716697936210132,
#    'Travel and transport': 0.5611510791366906,
#    'Retail': 0.31111111111111117},
#   'acc_score_class_wise': {'Games': 0.6862745098039216,
#    'Household': 0.4883720930232558,
#    'Services': 0.3246753246753247,
#    'Misc': 0.48717948717948717,
#    'Sports': 0.34615384615384615,
#    'Banking': 0.6363636363636364,
#    'Clothing': 0.6136363636363636,
#    'Industrial and agriculture': 0.375,
#    'Leisure': 0.5060240963855421,
#    'Publications media': 0.2222222222222222,
#    'Health': 0.3783783783783784,
#    'Car': 0.7831325301204819,
#    'Electronics': 0.6686390532544378,
#    'Cosmetics': 0.34782608695652173,
#    'Food and drink': 0.8586666666666667,
#    'Awareness': 0.6806083650190115,
#    'Travel and transport': 0.46987951807228917,
#    'Retail': 0.30434782608695654}},
#  'run_2': {'seed': 35258,
#   'accuracy': 0.6353427895981087,
#   'f1_score': 0.5062491120563968,
#   'f1_score_class_wise': {'Games': 0.6868686868686869,
#    'Household': 0.45652173913043476,
#    'Services': 0.4,
#    'Misc': 0.5555555555555556,
#    'Sports': 0.4193548387096774,
#    'Banking': 0.5714285714285714,
#    'Clothing': 0.5108695652173912,
#    'Industrial and agriculture': 0.2285714285714286,
#    'Leisure': 0.53125,
#    'Publications media': 0.11428571428571428,
#    'Health': 0.4785276073619632,
#    'Car': 0.791907514450867,
#    'Electronics': 0.6491228070175439,
#    'Cosmetics': 0.37500000000000006,
#    'Food and drink': 0.7974683544303797,
#    'Awareness': 0.6666666666666667,
#    'Travel and transport': 0.6013071895424836,
#    'Retail': 0.27777777777777773},
#   'acc_score_class_wise': {'Games': 0.6666666666666666,
#    'Household': 0.4883720930232558,
#    'Services': 0.4155844155844156,
#    'Misc': 0.5128205128205128,
#    'Sports': 0.5,
#    'Banking': 0.6363636363636364,
#    'Clothing': 0.5340909090909091,
#    'Industrial and agriculture': 0.16666666666666666,
#    'Leisure': 0.40963855421686746,
#    'Publications media': 0.1111111111111111,
#    'Health': 0.527027027027027,
#    'Car': 0.8253012048192772,
#    'Electronics': 0.6568047337278107,
#    'Cosmetics': 0.2608695652173913,
#    'Food and drink': 0.84,
#    'Awareness': 0.6653992395437263,
#    'Travel and transport': 0.5542168674698795,
#    'Retail': 0.21739130434782608}},
#  'run_3': {'seed': 80499,
#   'accuracy': 0.6317966903073287,
#   'f1_score': 0.489939505851124,
#   'f1_score_class_wise': {'Games': 0.7192982456140351,
#    'Household': 0.3448275862068966,
#    'Services': 0.34722222222222227,
#    'Misc': 0.5573770491803278,
#    'Sports': 0.3773584905660377,
#    'Banking': 0.5609756097560975,
#    'Clothing': 0.5157894736842105,
#    'Industrial and agriculture': 0.20689655172413793,
#    'Leisure': 0.5074626865671641,
#    'Publications media': 0.1904761904761905,
#    'Health': 0.43902439024390244,
#    'Car': 0.7741935483870968,
#    'Electronics': 0.6310160427807486,
#    'Cosmetics': 0.411764705882353,
#    'Food and drink': 0.817320703653586,
#    'Awareness': 0.6819787985865724,
#    'Travel and transport': 0.6068965517241379,
#    'Retail': 0.12903225806451613},
#   'acc_score_class_wise': {'Games': 0.803921568627451,
#    'Household': 0.3488372093023256,
#    'Services': 0.3246753246753247,
#    'Misc': 0.4358974358974359,
#    'Sports': 0.38461538461538464,
#    'Banking': 0.5227272727272727,
#    'Clothing': 0.5568181818181818,
#    'Industrial and agriculture': 0.125,
#    'Leisure': 0.40963855421686746,
#    'Publications media': 0.1111111111111111,
#    'Health': 0.6081081081081081,
#    'Car': 0.7951807228915663,
#    'Electronics': 0.6982248520710059,
#    'Cosmetics': 0.30434782608695654,
#    'Food and drink': 0.8053333333333333,
#    'Awareness': 0.7338403041825095,
#    'Travel and transport': 0.5301204819277109,
#    'Retail': 0.08695652173913043}},
#  'run_4': {'seed': 84464,
#   'accuracy': 0.6365248226950354,
#   'f1_score': 0.492384089505604,
#   'f1_score_class_wise': {'Games': 0.7032967032967032,
#    'Household': 0.4,
#    'Services': 0.39062499999999994,
#    'Misc': 0.4,
#    'Sports': 0.39999999999999997,
#    'Banking': 0.5517241379310344,
#    'Clothing': 0.547945205479452,
#    'Industrial and agriculture': 0.2702702702702703,
#    'Leisure': 0.4625850340136054,
#    'Publications media': 0.08,
#    'Health': 0.435374149659864,
#    'Car': 0.7884057971014492,
#    'Electronics': 0.6623376623376623,
#    'Cosmetics': 0.46913580246913583,
#    'Food and drink': 0.8076398362892225,
#    'Awareness': 0.6587183308494783,
#    'Travel and transport': 0.6583850931677019,
#    'Retail': 0.1764705882352941},
#   'acc_score_class_wise': {'Games': 0.6274509803921569,
#    'Household': 0.32558139534883723,
#    'Services': 0.3246753246753247,
#    'Misc': 0.28205128205128205,
#    'Sports': 0.34615384615384615,
#    'Banking': 0.5454545454545454,
#    'Clothing': 0.6818181818181818,
#    'Industrial and agriculture': 0.20833333333333334,
#    'Leisure': 0.40963855421686746,
#    'Publications media': 0.05555555555555555,
#    'Health': 0.43243243243243246,
#    'Car': 0.8192771084337349,
#    'Electronics': 0.6035502958579881,
#    'Cosmetics': 0.41304347826086957,
#    'Food and drink': 0.7893333333333333,
#    'Awareness': 0.8403041825095057,
#    'Travel and transport': 0.6385542168674698,
#    'Retail': 0.13043478260869565}}}

# %%
#function to compute average of all runs per class
from statistics import mean 
def compute_average_class_wise_metrics_runs(data):
    
    key_list=list(data.keys())
    
    #extract class names
    class_name_list=list(data[key_list[0]]['f1_score_class_wise'].keys())
    dict_f1_list={k:[] for k in class_name_list}
    dict_acc_list={k:[] for k in class_name_list}
    
    for key in key_list:
        
        #class_wise_f1
        
        f1_dict=data[key]['f1_score_class_wise']
        
        
        #class_wise_acc
        
        acc_dict=data[key]['acc_score_class_wise']
        
        for lb_k in list(f1_dict.keys()):
            dict_f1_list[lb_k].append(f1_dict[lb_k])
            dict_acc_list[lb_k].append(acc_dict[lb_k])
        
#     print(dict_f1_list)
#     print(dict_acc_list)
    
    #compute per class mean
    mean_dict_f1={k:[] for k in class_name_list}
    mean_dict_acc={k:[] for k in class_name_list}
    for k in list(dict_f1_list.keys()):
        
        mean_dict_f1[k]=mean(dict_f1_list[k])
        mean_dict_acc[k]=mean(dict_acc_list[k])
        
    
#     print(mean_dict_f1)
#     print(mean_dict_acc)
    
    return(mean_dict_f1,mean_dict_acc)
    
av_f1,av_acc=compute_average_class_wise_metrics_runs(av_data)
tv_f1,tv_acc=compute_average_class_wise_metrics_runs(tv_data)
a_max_f1,a_max_acc=compute_average_class_wise_metrics_runs(a_max_data)
d_max_f1,d_max_acc=compute_average_class_wise_metrics_runs(d_max_data)

# %%
av_f1
# Out:
# {'Games': 0.6110054136085115,
#  'Household': 0.4533260456355568,
#  'Services': 0.40115701385897834,
#  'Misc': 0.4255195078145898,
#  'Sports': 0.34360885491320275,
#  'Banking': 0.43673519006141703,
#  'Clothing': 0.5236760757943024,
#  'Industrial and agriculture': 0.4533050606113633,
#  'Leisure': 0.43629406792070863,
#  'Publications media': 0.09390476190476191,
#  'Health': 0.4902403567703561,
#  'Car': 0.785154213106567,
#  'Electronics': 0.6095287065271656,
#  'Cosmetics': 0.43483082138477025,
#  'Food and drink': 0.7756414483584452,
#  'Awareness': 0.6675987897785878,
#  'Travel and transport': 0.5830630668076158,
#  'Retail': 0.23546949899953454}

# %%
tv_f1
# Out:
# {'Games': 0.6859681988539983,
#  'Household': 0.44320744156685427,
#  'Services': 0.3881375313283208,
#  'Misc': 0.5295027419810447,
#  'Sports': 0.3827712372837144,
#  'Banking': 0.5643812193786962,
#  'Clothing': 0.5144980452026706,
#  'Industrial and agriculture': 0.33600931019221875,
#  'Leisure': 0.5084948382338009,
#  'Publications media': 0.14235838762646327,
#  'Health': 0.4480362098453028,
#  'Car': 0.7914560832340832,
#  'Electronics': 0.6329006982383376,
#  'Cosmetics': 0.42606670945258474,
#  'Food and drink': 0.7970448537866538,
#  'Awareness': 0.6671388004963409,
#  'Travel and transport': 0.6096121538371975,
#  'Retail': 0.2374149324035935}

# %%
a_max_f1
# Out:
# {'Games': 0.679198510346606,
#  'Household': 0.5207938700586321,
#  'Services': 0.45531149590646397,
#  'Misc': 0.5366119050516469,
#  'Sports': 0.3826975281019229,
#  'Banking': 0.6161011001639148,
#  'Clothing': 0.5437856986559102,
#  'Industrial and agriculture': 0.5092555694422951,
#  'Leisure': 0.5302055536435467,
#  'Publications media': 0.1353486141156306,
#  'Health': 0.5141382721767109,
#  'Car': 0.808372585303769,
#  'Electronics': 0.6585826717015151,
#  'Cosmetics': 0.44355886469833294,
#  'Food and drink': 0.7973924442467935,
#  'Awareness': 0.6977046364106982,
#  'Travel and transport': 0.6325578951521248,
#  'Retail': 0.29715338256079094}

# %%
d_max_f1
# Out:
# {'Games': 0.673747496996192,
#  'Household': 0.517504087514997,
#  'Services': 0.44069936571318064,
#  'Misc': 0.5373392556154255,
#  'Sports': 0.3706778662265162,
#  'Banking': 0.6081831758711956,
#  'Clothing': 0.5411468468048305,
#  'Industrial and agriculture': 0.49329173033881935,
#  'Leisure': 0.5245233075335477,
#  'Publications media': 0.12976261967806196,
#  'Health': 0.5058893108533821,
#  'Car': 0.8038496460816825,
#  'Electronics': 0.6553900430157219,
#  'Cosmetics': 0.44083901085899596,
#  'Food and drink': 0.7964335728215086,
#  'Awareness': 0.6975062183276514,
#  'Travel and transport': 0.6300942171479097,
#  'Retail': 0.2947860693538957}

# %%
 (0.9576934038836032+0.5228221235317971)/2
# Out:
# 0.7402577637077001

# %%
av_acc
# Out:
# {'Games': 0.6627450980392157,
#  'Household': 0.4790697674418605,
#  'Services': 0.36623376623376624,
#  'Misc': 0.3230769230769231,
#  'Sports': 0.33076923076923076,
#  'Banking': 0.39090909090909093,
#  'Clothing': 0.5795454545454545,
#  'Industrial and agriculture': 0.45,
#  'Leisure': 0.4506024096385542,
#  'Publications media': 0.06666666666666667,
#  'Health': 0.49729729729729727,
#  'Car': 0.7518072289156627,
#  'Electronics': 0.5881656804733728,
#  'Cosmetics': 0.3782608695652174,
#  'Food and drink': 0.8112,
#  'Awareness': 0.7095057034220532,
#  'Travel and transport': 0.5710843373493976,
#  'Retail': 0.2}

# %%
tv_acc
# Out:
# {'Games': 0.6862745098039216,
#  'Household': 0.44651162790697674,
#  'Services': 0.34805194805194806,
#  'Misc': 0.441025641025641,
#  'Sports': 0.3923076923076923,
#  'Banking': 0.5863636363636363,
#  'Clothing': 0.5522727272727272,
#  'Industrial and agriculture': 0.2833333333333333,
#  'Leisure': 0.4578313253012048,
#  'Publications media': 0.1111111111111111,
#  'Health': 0.4837837837837838,
#  'Car': 0.8012048192771084,
#  'Electronics': 0.6355029585798817,
#  'Cosmetics': 0.3739130434782609,
#  'Food and drink': 0.8170666666666667,
#  'Awareness': 0.7171102661596959,
#  'Travel and transport': 0.5783132530120482,
#  'Retail': 0.2}

# %%
a_max_acc
# Out:
# {'Games': 0.716078431372549,
#  'Household': 0.5367441860465116,
#  'Services': 0.39636363636363636,
#  'Misc': 0.4256410256410256,
#  'Sports': 0.37230769230769234,
#  'Banking': 0.5936363636363636,
#  'Clothing': 0.5959090909090909,
#  'Industrial and agriculture': 0.44,
#  'Leisure': 0.5060240963855421,
#  'Publications media': 0.09777777777777777,
#  'Health': 0.5210810810810811,
#  'Car': 0.7971084337349398,
#  'Electronics': 0.6601183431952663,
#  'Cosmetics': 0.3782608695652174,
#  'Food and drink': 0.83328,
#  'Awareness': 0.752851711026616,
#  'Travel and transport': 0.6106024096385542,
#  'Retail': 0.21913043478260869}

# %%
d_max_acc
# Out:
# {'Games': 0.7184313725490196,
#  'Household': 0.5311627906976744,
#  'Services': 0.38181818181818183,
#  'Misc': 0.4287179487179487,
#  'Sports': 0.3646153846153846,
#  'Banking': 0.5918181818181818,
#  'Clothing': 0.5909090909090909,
#  'Industrial and agriculture': 0.43833333333333335,
#  'Leisure': 0.5040963855421686,
#  'Publications media': 0.09555555555555555,
#  'Health': 0.5205405405405406,
#  'Car': 0.7944578313253012,
#  'Electronics': 0.6539644970414201,
#  'Cosmetics': 0.3817391304347826,
#  'Food and drink': 0.83072,
#  'Awareness': 0.7412927756653992,
#  'Travel and transport': 0.6163855421686747,
#  'Retail': 0.22434782608695653}

# %%
dict_sample_a_max=[]
for key in list(a_max_f1.keys()):
    if((a_max_f1[key]>av_f1[key]) and (a_max_f1[key]>tv_f1[key])):
        dict_sample_a_max.append({'topic':key,'a_max':a_max_f1[key]*100,'av':av_f1[key]*100, 'tv':tv_f1[key]*100})

# %%
len(dict_sample_a_max)
# Out:
# 15

# %%
dict_sample_a_max
# Out:
# [{'topic': 'Household',
#   'a_max': 0.5207938700586321,
#   'av': 0.4533260456355568,
#   'tv': 0.44320744156685427},
#  {'topic': 'Services',
#   'a_max': 0.45531149590646397,
#   'av': 0.40115701385897834,
#   'tv': 0.3881375313283208},
#  {'topic': 'Misc',
#   'a_max': 0.5366119050516469,
#   'av': 0.4255195078145898,
#   'tv': 0.5295027419810447},
#  {'topic': 'Banking',
#   'a_max': 0.6161011001639148,
#   'av': 0.43673519006141703,
#   'tv': 0.5643812193786962},
#  {'topic': 'Clothing',
#   'a_max': 0.5437856986559102,
#   'av': 0.5236760757943024,
#   'tv': 0.5144980452026706},
#  {'topic': 'Industrial and agriculture',
#   'a_max': 0.5092555694422951,
#   'av': 0.4533050606113633,
#   'tv': 0.33600931019221875},
#  {'topic': 'Leisure',
#   'a_max': 0.5302055536435467,
#   'av': 0.43629406792070863,
#   'tv': 0.5084948382338009},
#  {'topic': 'Health',
#   'a_max': 0.5141382721767109,
#   'av': 0.4902403567703561,
#   'tv': 0.4480362098453028},
#  {'topic': 'Car',
#   'a_max': 0.808372585303769,
#   'av': 0.785154213106567,
#   'tv': 0.7914560832340832},
#  {'topic': 'Electronics',
#   'a_max': 0.6585826717015151,
#   'av': 0.6095287065271656,
#   'tv': 0.6329006982383376},
#  {'topic': 'Cosmetics',
#   'a_max': 0.44355886469833294,
#   'av': 0.43483082138477025,
#   'tv': 0.42606670945258474},
#  {'topic': 'Food and drink',
#   'a_max': 0.7973924442467935,
#   'av': 0.7756414483584452,
#   'tv': 0.7970448537866538},
#  {'topic': 'Awareness',
#   'a_max': 0.6977046364106982,
#   'av': 0.6675987897785878,
#   'tv': 0.6671388004963409},
#  {'topic': 'Travel and transport',
#   'a_max': 0.6325578951521248,
#   'av': 0.5830630668076158,
#   'tv': 0.6096121538371975},
#  {'topic': 'Retail',
#   'a_max': 0.29715338256079094,
#   'av': 0.23546949899953454,
#   'tv': 0.2374149324035935}]

# %%
dict_sample_d_max=[]
for key in list(d_max_f1.keys()):
    if((d_max_f1[key]>av_f1[key]) and (d_max_f1[key]>tv_f1[key])):
        dict_sample_d_max.append({'topic':key,'d_max':d_max_f1[key]*100,'av':av_f1[key]*100, 'tv':tv_f1[key]*100})

# %%
dict_sample_d_max
# Out:
# [{'topic': 'Household',
#   'd_max': 51.7504087514997,
#   'av': 45.33260456355568,
#   'tv': 44.32074415668543},
#  {'topic': 'Services',
#   'd_max': 44.06993657131807,
#   'av': 40.115701385897836,
#   'tv': 38.813753132832076},
#  {'topic': 'Misc',
#   'd_max': 53.73392556154255,
#   'av': 42.55195078145898,
#   'tv': 52.950274198104474},
#  {'topic': 'Banking',
#   'd_max': 60.818317587119566,
#   'av': 43.6735190061417,
#   'tv': 56.438121937869624},
#  {'topic': 'Clothing',
#   'd_max': 54.11468468048305,
#   'av': 52.36760757943024,
#   'tv': 51.449804520267065},
#  {'topic': 'Industrial and agriculture',
#   'd_max': 49.329173033881936,
#   'av': 45.330506061136326,
#   'tv': 33.600931019221875},
#  {'topic': 'Leisure',
#   'd_max': 52.45233075335477,
#   'av': 43.62940679207086,
#   'tv': 50.84948382338009},
#  {'topic': 'Health',
#   'd_max': 50.58893108533821,
#   'av': 49.02403567703561,
#   'tv': 44.803620984530276},
#  {'topic': 'Car',
#   'd_max': 80.38496460816825,
#   'av': 78.51542131065669,
#   'tv': 79.14560832340833},
#  {'topic': 'Electronics',
#   'd_max': 65.53900430157219,
#   'av': 60.95287065271656,
#   'tv': 63.29006982383376},
#  {'topic': 'Cosmetics',
#   'd_max': 44.0839010858996,
#   'av': 43.48308213847702,
#   'tv': 42.60667094525847},
#  {'topic': 'Awareness',
#   'd_max': 69.75062183276513,
#   'av': 66.75987897785878,
#   'tv': 66.71388004963408},
#  {'topic': 'Travel and transport',
#   'd_max': 63.00942171479097,
#   'av': 58.30630668076158,
#   'tv': 60.96121538371975},
#  {'topic': 'Retail',
#   'd_max': 29.478606935389568,
#   'av': 23.546949899953454,
#   'tv': 23.74149324035935}]

# %%
    import pandas as pd 
    #def create_df_from_dict(dict_list):
    
    topic_list=[]
    a_max_list=[]
    av_list=[]
    tv_list=[]
    
    for i in range(len(dict_sample_a_max)):
        
        topic_list.append(dict_sample_a_max[i]['topic'])
        a_max_list.append(dict_sample_a_max[i]['a_max']*100)
        av_list.append(dict_sample_a_max[i]['av']*100)
        tv_list.append(dict_sample_a_max[i]['tv']*100)
        
    df=pd.DataFrame({'Topic':topic_list,
                    'A_max':a_max_list,
                    'AV-Tx':av_list,
                    'TV-Tx':tv_list})

# %%
df
# Out:
#                          Topic      A_max         AV         TV
# 0                    Household  52.079387  45.332605  44.320744
# 1                     Services  45.531150  40.115701  38.813753
# 2                         Misc  53.661191  42.551951  52.950274
# 3                      Banking  61.610110  43.673519  56.438122
# 4                     Clothing  54.378570  52.367608  51.449805
# 5   Industrial and agriculture  50.925557  45.330506  33.600931
# 6                      Leisure  53.020555  43.629407  50.849484
# 7                       Health  51.413827  49.024036  44.803621
# 8                          Car  80.837259  78.515421  79.145608
# 9                  Electronics  65.858267  60.952871  63.290070
# 10                   Cosmetics  44.355886  43.483082  42.606671
# 11              Food and drink  79.739244  77.564145  79.704485
# 12                   Awareness  69.770464  66.759879  66.713880
# 13        Travel and transport  63.255790  58.306307  60.961215
# 14                      Retail  29.715338  23.546950  23.741493

# %%
    import pandas as pd 
    #def create_df_from_dict(dict_list):
    
    topic_list=[]
    d_max_list=[]
    av_list=[]
    tv_list=[]
    
    for i in range(len(dict_sample_d_max)):
        
        topic_list.append(dict_sample_d_max[i]['topic'])
        d_max_list.append(dict_sample_d_max[i]['d_max'])
        av_list.append(dict_sample_d_max[i]['av'])
        tv_list.append(dict_sample_d_max[i]['tv'])
        
    df=pd.DataFrame({'Topic':topic_list,
                    'D_max':d_max_list,
                    'AV-Tx':av_list,
                    'TV-Tx':tv_list})

# %%
df
# Out:
#                          Topic      D_max      AV-Tx      TV-Tx
# 0                    Household  51.750409  45.332605  44.320744
# 1                     Services  44.069937  40.115701  38.813753
# 2                         Misc  53.733926  42.551951  52.950274
# 3                      Banking  60.818318  43.673519  56.438122
# 4                     Clothing  54.114685  52.367608  51.449805
# 5   Industrial and agriculture  49.329173  45.330506  33.600931
# 6                      Leisure  52.452331  43.629407  50.849484
# 7                       Health  50.588931  49.024036  44.803621
# 8                          Car  80.384965  78.515421  79.145608
# 9                  Electronics  65.539004  60.952871  63.290070
# 10                   Cosmetics  44.083901  43.483082  42.606671
# 11                   Awareness  69.750622  66.759879  66.713880
# 12        Travel and transport  63.009422  58.306307  60.961215
# 13                      Retail  29.478607  23.546950  23.741493
